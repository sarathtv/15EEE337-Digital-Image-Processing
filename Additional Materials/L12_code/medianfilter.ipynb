# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
img = cv2.imread('/content/drive/MyDrive/images/brain.jpeg')
cv2_imshow(img)

# %%
median = cv2.medianBlur(img, 5)
compare = np.concatenate((img, median), axis=1) #side by side comparison

cv2_imshow(compare)
# Out:
# <PIL.Image.Image image mode=RGB size=1074x537 at 0x7FADBF4B2050>

# %%
from PIL import Image
from PIL import ImageFilter

# Method to apply the filter
def applyMaximumFilter(image):
    return image.filter(ImageFilter.MaxFilter);

# Load the image
imagePath   = "/content/drive/MyDrive/images/raindrop.png";
imageObject = Image.open(imagePath);

# Apply maximum filter
filterApplied = imageObject;
for i in range(0, 3):
    print(i);
    filterApplied = applyMaximumFilter(filterApplied);

# Display images
imageObject
# Out:
# 0
# 1
# 2
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=553x325 at 0x7FADCFAF71D0>

# %%
filterApplied
# Out:
# <PIL.Image.Image image mode=RGBA size=553x325 at 0x7FADBF4C4350>

# %%
# Method to apply the filter
def applyMinimumFilter(image):
    return image.filter(ImageFilter.MinFilter);

# Load the image
imagePath   = "/content/drive/MyDrive/images/raindrop.png";
imageObject = Image.open(imagePath);

# Apply maximum filter
filterApplied = imageObject;
for i in range(0, 3):
    print(i);
    filterApplied = applyMinimumFilter(filterApplied);

# Display images
imageObject
# Out:
# 0
# 1
# 2
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=553x325 at 0x7FADC0D2BC10>

# %%
filterApplied
# Out:
# <PIL.Image.Image image mode=RGBA size=553x325 at 0x7FADBF4C4310>
