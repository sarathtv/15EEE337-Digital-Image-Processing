# %%
import cv2
from skimage import io, img_as_float
from skimage.filters import gaussian
from google.colab.patches import cv2_imshow

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# https://docs.opencv.org/4.5.3/d4/d86/group__imgproc__filter.html

# %%
#Needs 8 bit, not float.
img_gaussian_noise = cv2.imread('/content/drive/MyDrive/images/Osteosarcoma_01_25Sigma_noise.tif', 0)
img_salt_pepper_noise = cv2.imread('/content/drive/MyDrive/images//Osteosarcoma_01_8bit_salt_pepper.tif', 0)

img = img_gaussian_noise

gaussian_using_cv2 = cv2.GaussianBlur(img, (3,3), 0, borderType=cv2.BORDER_CONSTANT)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=1376x1104 at 0x7FAF6903BF90>

# %%
cv2_imshow(gaussian_using_cv2)
# Out:
# <PIL.Image.Image image mode=L size=1376x1104 at 0x7FAF6903BDD0>
