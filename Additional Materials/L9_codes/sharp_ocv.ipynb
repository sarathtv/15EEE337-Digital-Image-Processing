# %%
#Importing libraries)
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
#using in local machine ... cv2.imshow

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Read input image
img = cv2.imread('/content/drive/MyDrive/images/L9/img1.png')

# %%
img = cv2.resize(img , (400 , 400))

#Display the input image)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F60B5FA1450>

# %%
#Let's make a kernel which we will slide over our image(convolution))
kernel = np.array([[-1 , -1 , -1] , [-1 , 8.5 , -1] ,[-1 , -1 , -1]])

#Now we will perform convolution using open cv for shapening ur image)
sharp_img = cv2.filter2D(img , -1 , kernel = kernel)
cv2_imshow(sharp_img)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F60A53E93D0>
